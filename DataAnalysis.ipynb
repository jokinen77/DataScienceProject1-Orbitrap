# %% [markdown]
# # Development version 16.5.21-21:00
#
# Data analysis code for Orbitool spectra.
#
# NOTE: Before using this, update the file directory names in the following modules:
#
# readSpectrum, Main program, readMultipleSpectra
#
# Run Main program, if you want to study one spectrum.
# Run readMultipleSpectra, if you want to study many spectra at the same time.

# %%
import numpy as np

# This method finds the location of all peaks in the full spectrum
# Output (Indices) contains the start index and end index of each peak
# It is assumed that the structure of the data is coherent.

def findPeakIndices(data):

# each peak in 'data' starts and ends with a zero
# so that there are two zeros between each peak
# =============================================

    n = int(round(sum(data.iloc[:,1] == 0)/2)+1) # n is just the upper limit for the number of peaks
    indices = np.zeros([n,2], dtype="uint32")    # true n may be lower

    ii = 0                                       # index for indices
    indices[ii,0] = 0
    i = 1
    while i < len(data):
        if data.iloc[i,1] == 0:     
            if (i+1) == len(data):
                indices[ii,1] = i
            elif data.iloc[i+1,1] == 0:
                indices[ii,1] = i
                ii = ii+1
                i = i+1
                indices[ii,0] = i
        i = i+1
        
# n may be too large, because there are sometimes single zeros within peaks
# therefore, extra indices are cut out
    indices = indices[0:ii+1,:]
    return indices

# KOj 6.4. zeros in the beginning and end are now included in indexed peaks
# Another way to save the indices could also be used: 
# add 1 to every indices[ii,0]
# minus 1 from every indices[ii,1]

# %% [markdown]
# ## getMean
#
# This method is called "weighted mean" in reports.
#
# It gives the mean of one peak and the variance calculated from the mean value (common practise), so it is not the "true" variance calculated from the data.

# %%
from scipy.optimize import leastsq
import numpy as np
import math

def getMean(peak):
    mu = np.average(peak.iloc[:,0], weights=peak.iloc[:,1])  # painotettu keskiarvo

    sigma = mu/(280000*2*np.sqrt(2*np.log(2)))
    fitfunc =  lambda p, x: p[0]*np.exp(-0.5*((x-p[1])/sigma)**2)
    errfunc  = lambda p, x, y: (y - fitfunc(p, x))
    init  = [1.0, mu]

    out = leastsq(errfunc, init, args=(peak.iloc[:,0], peak.iloc[:,1]))                 
    c = out[0]
    return sigma, c[1]

# %% [markdown]
# ## getAllMeans
#
# This method calculates various values from all peaks in one spectrum.

# %%
import numpy as np

def getAllMeans(data):
    indices = findPeakIndices(data)
    peakAreas = getAllAreas(data,indices)
    peakSkews = getAllSkews(data,indices)

    n = len(indices)  
    means = np.zeros(n)
    sigmas = np.zeros(n)
    lefts = np.zeros(n)
    rights = np.zeros(n)
    for i in range(n):
        peak = data.iloc[indices[i,0]:indices[i,1]+1,:]
        sigmas[i], means[i] = getMean(peak)
        lefts[i] = indices[i,0]
        rights[i] = indices[i,1]

    return sigmas, means, peakAreas, peakSkews, lefts, rights

# %% [markdown]
# ## getArea
#
# Actual area of the peak is calculated from the peak histogram.

# %%
import numpy as np

def getArea(peak):
    zum = 0         # m/z channels have different widths, but we count intensities
    for i in range(1,len(peak)-1):
        zum = zum + peak.iloc[i,1]

# It was realized that the next line does not give proper counts
#    zum = zum * (peak.iloc[len(peak)-1,0]-peak.iloc[1,0])/(len(peak)-2)

    return zum

# %%
import pandas as pd
import numpy as np

def getAllAreas(data, indices):

    n = len(indices)
    areas = np.zeros(n)
    for i in range(n):
        peak = data.iloc[indices[i,0]:indices[i,1]+1,:]
        areas[i] = getArea(peak)
#    print("all areas ok")
    return areas

# %% [markdown]
# ## getSkew
#
# Skewness of one peak is calculated from the peak data.

# %%
import numpy as np
# Pandas has its own skew method.
import pandas as pd

def getSkew(peak):
    dta=peak.iloc[:,1]
    skw = dta.skew(axis = 0)
    return skw

# %%
import pandas as pd
import numpy as np

def getAllSkews(data, indices):

    n = len(indices)
    skews = np.zeros(n)
    for i in range(n):
        peak = data.iloc[indices[i,0]:indices[i,1]+1,:]
        skews[i] = getSkew(peak)

    return skews

# %% [markdown]
# ## getPeak
#
# This method returns the peak of interest rom the peaklist.

# %%
import pandas as pd
import numpy as np

def getPeak(i, peaklist, interest):
    ix = 0
    # ion index i is here changed to array index ix 
    for j in range(len(peaklist)):
        if peaklist.iloc[j,9] == i:
            ix = j
    if interest:
        print("Peak of interest: ",peaklist.iloc[ix,0])

    left = int(peaklist.iloc[ix,7])
    right = int(peaklist.iloc[ix,8])
    peak = data[left:right+1]
#    print("L R: ",left,right)    
#    print(peak)  # To show the actual peak data in numbers
    return ix, peak

# %% [markdown]
# ## addGaussians
#
# Gaussian model from lmfit library is fitted on each peak.
#
# Center, sigma, and fwhm are saved in the peaklist dataframe.

# %%
import pandas as pd
import numpy as np
from lmfit.models import GaussianModel, LorentzianModel   # , VoigtModel
#from lmfit import fit_report                             # was needed for the VoigtModel

def addGaussians(peaklist):
    
    for i in range(len(peaklist)):  
        index = peaklist.iloc[i,9]                                 #  9 for the INDEX column
        ix, peak = getPeak(index,peaklist, False)
        df = pd.DataFrame(peak, columns = ['x','y'])
        cc = len(peak.iloc[:,0])
        df['index'] = np.arange(cc).reshape(cc,1)
        df['x'] = peak.iloc[:,0]
        df['y'] = peak.iloc[:,1]
        df.set_index('index', inplace = True)

        model = GaussianModel()
        params = model.guess(df['y'], x=df['x'])
        result = model.fit(df['y'], params, x=df['x'])
        for parname, param in result.params.items():
#            print("%s = %f +/- %f " % (parname, param.value, param.stderr))
            if parname == 'center':
                centerGv = param.value
            if parname == 'sigma':
                sigmaGv = param.value
            if parname == 'fwhm':
                fwhmGv = param.value
# The height part only for the single spectrum analysis for now
#            if parname == 'height':
#                heightGv = param.value
                
        peaklist.iloc[i,10] = centerGv
        peaklist.iloc[i,11] = sigmaGv
        peaklist.iloc[i,12] = fwhmGv


        model = LorentzianModel()
        params = model.guess(df['y'], x=df['x'])
        result = model.fit(df['y'], params, x=df['x'])
        for parname, param in result.params.items():
#            print("%s = %f +/- %f " % (parname, param.value, param.stderr))
            if parname == 'center':
                centerLv = param.value
            if parname == 'sigma':
                sigmaLv = param.value
            if parname == 'fwhm':
                fwhmLv = param.value
                
        peaklist.iloc[i,13] = centerLv
        peaklist.iloc[i,14] = sigmaLv
        peaklist.iloc[i,15] = fwhmLv
        
#        peaklist.iloc[i,16] = heightGv   # This line produced height data for one graph

# This Voigt model is not in use anymore.
# Originally, after comparing peak fit results for one peak from 10 spectra, 
# error from this fit was in average about 25% more than from the best three fits.

#        model = VoigtModel()
#        pars = model.guess(df['y'], x=df['x'])
#        pars['gamma'].set(value=0.7, vary=True, expr='')
#        result  = model.fit(df['y'], pars, x=df['x'])
        
#        for parname, param in result.pars.items():
#            print("%s = %f +/- %f " % (parname, param.value, param.stderr))
#            if parname == 'center':
#                centerVv = param.value
#            if parname == 'sigma':
#                sigmaVv = param.value
#            if parname == 'fwhm':
#                fwhmVv = param.value
                
#        peaklist.iloc[i,16] = centerVv
#        peaklist.iloc[i,17] = sigmaVv
#        peaklist.iloc[i,18] = fwhmVv

# %% [markdown]
# ## plotPeak
#
# Plot the peak i from the peaklist

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def plotPeak(i, peaklist):

    ix, peak = getPeak(i, peaklist, True)
    
    plt.plot(peak.iloc[:,0],peak.iloc[:,1])
    plt.vlines(peaklist.iloc[ix,2],0,max(peak.iloc[:,1]))
    plt.vlines(peaklist.iloc[ix,1],0,max(peak.iloc[:,1]), color = "green")

    plt.legend(["Data","Mean from data","True mean"])
    plt.title(peaklist.iloc[ix,0])
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#from lmfit.models import LorentzianModel
from lmfit.models import GaussianModel

def plotGaussian(i, peaklist):
    
    ix, peak = getPeak(i, peaklist, True)  
    
# read the data into a pandas DataFrame, and use the ‘x’ and ‘y’ columns:
# Sata is already in such a dataframe
# dframe = pd.read_csv('peak.csv')

    df = pd.DataFrame(peak, columns = ['x','y'])
    cc = len(peak.iloc[:,0])
    df['index'] = np.arange(cc).reshape(cc,1)
    df['x'] = peak.iloc[:,0]
    df['y'] = peak.iloc[:,1]
#    df['y'] = np.log(peak.iloc[:,1] )  # needs improvement.. log was to handle skewed peaks
    df.set_index('index', inplace = True)
    print(df)

#    model = LorentzianModel()   # was not as good as Gaussian
    model = GaussianModel()
    params = model.guess(df['y'], x=df['x'])
    result = model.fit(df['y'], params, x=df['x'])

# and gives the plot and fitting results below:

    result.plot_fit()
    plt.show()

    print(result.fit_report())

# %% [markdown]
# ## identifyPeaks
#
# A peak is identified when the distance from the mean is less than maxDistance (of absolute mass)
#
# NOTE: there may be several peaks within that distance. Needs some improvement to handle that case.

# %%
import pandas as pd
import numpy as np

# maxDistance below = 'th' in JKolis's code

def identifyPeaks(data, peaklist, maxDistance):    
    peaklist['observed'] = np.zeros(len(peaklist['mz'])) #2
    peaklist['peak'] = np.zeros(len(peaklist['mz']), dtype="uint32")     #3
    peaklist['area'] = np.zeros(len(peaklist['mz']))     #4
    peaklist['skew'] = np.zeros(len(peaklist['mz']))     #5
    peaklist['sigma'] = np.zeros(len(peaklist['mz']))    #6
    peaklist['lefti']  = np.zeros(len(peaklist['mz']), dtype="uint32")   #7
    peaklist['righti'] = np.zeros(len(peaklist['mz']), dtype="uint32")   #8
#    peaklist['centerG'] = np.zeros(len(peaklist['mz']))   #9
#    peaklist['sigmaG']  = np.zeros(len(peaklist['mz']))   #10
#    peaklist['fwhmG'] = np.zeros(len(peaklist['mz']))   #11    

    sigmas, peakMeans, peakAreas, peakSkews, lefts, rights = getAllMeans(data)
    trueValue = peaklist['mz'].to_numpy()     # get only the mz values from the peaklist

    for i in range(len(trueValue)):
        if min(abs(peakMeans - trueValue[i])) < maxDistance:      # there is at least one
            ind = np.argmin(abs(peakMeans - trueValue[i]))
            peaklist.iloc[i,2] = peakMeans[ind]
            peaklist.iloc[i,3] = np.argmin(abs(peakMeans - trueValue[i]))
            peaklist.iloc[i,4] = peakAreas[ind]
            peaklist.iloc[i,5] = peakSkews[ind]
            peaklist.iloc[i,6] = sigmas[ind]
            peaklist.iloc[i,7] = int(lefts[ind])
            peaklist.iloc[i,8] = int(rights[ind])

    unidentified = np.linspace(0, len(trueValue)-1, len(trueValue))
    unidentified = unidentified[peaklist['observed'].to_numpy() == 0]
  
    identified = np.linspace(0, len(trueValue)-1, len(trueValue))
    identified = identified[peaklist['observed'].to_numpy() != 0]    

#    unidentified: 'observed' == 0, because it never got any actual value

    return peaklist.drop(unidentified)

# %% [markdown]
# ## readSpectrum
#
# Change the name of the 'dataDir' to match your own folder of spectra.
#
# Parameter n refers to the nth file in your folder.

# %%
# Method to read in one spectrum
# You need to give the folder name in this method

# A large number of averaged, denoised spectra was exported from Orbitool into folders.
# Exported with Antonio's "all denoised" button (not available in the prime Orbitool).

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import glob

def readSpectrum(n):
    dataDir = glob.glob("C:/datascienceproject/raw data/small mass deviation/deno201117n10/*.csv")
    fileName = dataDir[n]
    print(n, " File name: ",fileName)
    df = pd.read_csv(fileName, sep=",")

    print("Shape:      {}, {}".format(*df.shape))
    print()
    data = df.iloc[0:,:2].astype("float64")
    return(data)

# %% [markdown]
# ## "Main program"
#
# Change the name of the 'ionFolder' to match your own folder.
#
# NOTE: Remember to give the 'spectrumNumber', the nth file in the folder of spectra to be read.
#
# NOTE: The spectrumNumber of the first file in the folder is 0.

# %%
# Main program here

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

spectrumNumber = 0         
data = readSpectrum(spectrumNumber)    # Read the nth file in the folder of spectra

# print(data[340:353])      # Just in case, if you want to print some values from the dataframe

ionFolder = "<add your folder name here>/KOionfolder/"  # This has a different structure than the original ion file
                                                        # The first two lines were removed, only the data remaining
ionFileName = ionFolder + "Allions1ex.csv"
peaklist = identifyPeaks(data, pd.read_csv(ionFileName, sep=","), 0.001)
# Rightmost value just above is the maximum alloved distance between true and observed peak
# Note that as it is now, it is the same throughout the whole mass range.
# It could also be relative to mass.

peaklist['idx'] = peaklist.index.to_numpy()    # Add index value into column 9

peaklist['centerG'] = np.zeros(len(peaklist['mz']))   #10
peaklist['sigmaG']  = np.zeros(len(peaklist['mz']))   #11
peaklist['fwhmG'] = np.zeros(len(peaklist['mz']))   #12  

peaklist['centerL'] = np.zeros(len(peaklist['mz']))   #13
peaklist['sigmaL']  = np.zeros(len(peaklist['mz']))   #14
peaklist['fwhmL'] = np.zeros(len(peaklist['mz']))   #15 
peaklist['heightG'] = np.zeros(len(peaklist['mz']))   #16
#peaklist['centerV'] = np.zeros(len(peaklist['mz']))   #16    # We skip using these
#peaklist['sigmaV']  = np.zeros(len(peaklist['mz']))   #17
#peaklist['fwhmV'] = np.zeros(len(peaklist['mz']))   #18 

addGaussians(peaklist)

#print(peaklist)

peaklist['error'] = peaklist['observed'] - peaklist['mz'] # 17
peaklist['errorG'] = peaklist['centerG'] - peaklist['mz'] # 18
peaklist['errorL'] = peaklist['centerL'] - peaklist['mz'] # 19

print(peaklist)

print("Number of actual recognized peaks: ",len(peaklist))
pd.set_option('display.max_rows', len(peaklist))
print(peaklist)   # Helps to find the number of the peak of interest
pd.reset_option('display.max_rows')



# Plot some interesting graphs

peaklist0 = peaklist.copy()
peaklist0 = peaklist0[peaklist0.loc[:,'idx'] != 1]     # Big NO3- peak
peaklist0 = peaklist0[peaklist0.loc[:,'idx'] != 29]    # Another big peak

xmz0 = peaklist0['mz']
ydiff0 = peaklist0['observed'] - peaklist0['mz'] 
names0 = peaklist0['formula']
pit0 = len(xmz0)

# This first one has formula annotations in the graph

xmz = peaklist['mz']
ydiff = peaklist['observed'] - peaklist['mz']
names = peaklist['formula']
pit = len(xmz)

y = ydiff
x = xmz
fig = plt.figure()
plt.scatter(x,y)

k = names
# To see the names of compounds in the graph, uncomment these lines:
ax = fig.add_subplot(111)   # subplot not working as expected
for i,j,k in zip(x,y,k):
    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Molar mass (m/z)")
plt.ylabel("Error (Observed m/z -  true m/z)")
#plt.figure(figsize=(3,2))           # not working right
#plt.figure(figsize=(6, 4), dpi=70)  # not working right
plt.show()


# --------------------------------------------

logarea = np.log(peaklist['area'])
x = logarea
y = ydiff
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Log(peak area)")
plt.ylabel("Error (Observed m/z -  true m/z)")
plt.show()


logarea0 = np.log(peaklist0['area'])
x = logarea0
y = ydiff0
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Log(peak area)")
plt.ylabel("Error (Observed m/z -  true m/z)")
plt.show()

# --------------------------------------------


#x =  1000000*peaklist['fwhmG'] / peaklist['heightG']
#y = peaklist['centerG'] - peaklist['mz']
#fig = plt.figure()
#plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

#plt.xlabel("1000000 * Peak fwhm / peak height")
#plt.ylabel("Error (Observed m/z -  true m/z)")
#plt.show()


#x = 1000000*peaklist0['fwhmG'] / peaklist0['heightG']
#y = peaklist0['centerG'] - peaklist0['mz']
#fig = plt.figure()
#plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#k = names
#ax1 = fig.add_subplot(111)
#for i,j,k in zip(x,y,k):
#    ax1.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

#plt.xlabel("1000000 * Peak fwhm / peak height")
#plt.ylabel("Error (Observed m/z -  true m/z)")
#plt.show()

# --------------------------------------------

x = peaklist['sigmaG']
y = peaklist['centerG'] - peaklist['mz']
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Peak sigma")
plt.ylabel("Error (Gaussian fit m/z -  true m/z)")
plt.show()


x = peaklist0['sigmaG']
y = peaklist0['centerG'] - peaklist0['mz']
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Peak sigma")
plt.ylabel("Error (Gaussian fit m/z -  true m/z)")
plt.show()

# --------------------------------------------

x = peaklist['skew']
y = ydiff
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Peak skewness")
plt.ylabel("Error (Observed m/z -  true m/z)")
plt.show()


x = peaklist0['skew']
y = ydiff0
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Peak skewness")
plt.ylabel("Error (Observed m/z -  true m/z)")
plt.show()

# --------------------------------------------

print()
print("If skewness is less than -1 or greater than 1, the distribution is highly skewed.")
print("If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.")
print("If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.")
print()
print("Negative skewness: peak top is to the right from the mean (bigger tail on the left).")

x = logarea
y = peaklist['skew']
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Log (peak area)")
plt.ylabel("Peak skewness")
plt.show()


x = logarea0
y = peaklist0['skew']
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Log (peak area)")
plt.ylabel("Peak skewness")
plt.show()

# --------------------------------------------

x = peaklist['sigma']
y = peaklist['sigmaG']/peaklist['sigma']
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Sigma based on mz")
plt.ylabel("Sigma from Gaussian fit")
plt.title("Sigma mz / Sigma Gaussian fit")
plt.show()



x = peaklist['mz']
y = peaklist['errorG'] - peaklist['error']
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("mz")
plt.ylabel("Error(Gaussian fit) - Error(weighted mean)")
plt.title("Difference between errors")
plt.show()


x = peaklist['mz']
y = peaklist['errorL'] - peaklist['error']
fig = plt.figure()
plt.scatter(x,y)

# To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("mz")
plt.ylabel("Error(Lorentzian fit) - Error(weighted mean)")
plt.title("Difference between errors")
plt.show()
# Out:
# 0  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T16-56-06.csv
# Shape:      1593, 2
#
#             formula          mz    observed  peak          area      skew  \
# 1              O3N-   61.988366   61.988375     5  1.656485e+07  6.677467
# 2          O3N[15]-   62.985401   62.985424    10  5.582311e+04  0.964888
# 3         O2O[17]N-   62.992584   62.992606    11  1.414741e+04  0.875841
# 4         O2O[18]N-   63.992613   63.992622    12  9.802709e+04  0.985926
# 8           C4H5O2-   85.029503   85.029595    15  1.381071e+03  0.469239
# ..              ...         ...         ...   ...           ...       ...
# 254  C9C[13]H16O9N-  295.086410  295.086283    95  3.142938e+03  0.137284
# 262     C14H16O5NF-  297.101799  297.101966    96  1.473922e+03  0.891939
# 269     C10H14O10N-  308.062319  308.062254    97  6.353544e+03  0.464229
# 274     C10H16O10N-  310.077969  310.077730    98  2.640839e+03  0.321048
# 282     C10H14O11N-  324.057234  324.056963    99  1.937491e+03  0.370302
#
#         sigma  lefti  righti  idx     centerG    sigmaG     fwhmG     centerL  \
# 1    0.000094     73     276    1   61.988375  0.000048  0.000112   61.988375
# 2    0.000096    355     368    2   62.985424  0.000049  0.000116   62.985424
# 3    0.000096    369     380    3   62.992604  0.000045  0.000107   62.992604
# 4    0.000097    381     394    4   63.992621  0.000050  0.000118   63.992621
# 8    0.000129    423     432    8   85.029593  0.000074  0.000174   85.029594
# ..        ...    ...     ...  ...         ...       ...       ...         ...
# 254  0.000448   1379    1387  254  295.086282  0.000481  0.001133  295.086285
# 262  0.000451   1388    1398  262  297.101966  0.000435  0.001023  297.101973
# 269  0.000467   1399    1408  269  308.062252  0.000498  0.001173  308.062255
# 274  0.000470   1409    1418  274  310.077730  0.000538  0.001268  310.077730
# 282  0.000491   1419    1427  282  324.056962  0.000497  0.001170  324.056966
#
#        sigmaL     fwhmL  heightG     error    errorG    errorL
# 1    0.000044  0.000088      0.0  0.000009  0.000008  0.000008
# 2    0.000046  0.000092      0.0  0.000023  0.000022  0.000023
# 3    0.000042  0.000084      0.0  0.000022  0.000021  0.000020
# 4    0.000047  0.000093      0.0  0.000009  0.000008  0.000008
# 8    0.000074  0.000148      0.0  0.000092  0.000090  0.000091
# ..        ...       ...      ...       ...       ...       ...
# 253  0.000518  0.001037      0.0  2.410838e-04  2.409016e-04  2.406709e-04
# 254  0.000484  0.000968      0.0 -1.262656e-04 -1.279267e-04 -1.245499e-04
# 262  0.000401  0.000803      0.0  1.661637e-04  1.663835e-04  1.740582e-04
# 269  0.000485  0.000970      0.0 -6.528534e-05 -6.697758e-05 -6.380643e-05
# 274  0.000525  0.001050      0.0 -2.390390e-04 -2.388583e-04 -2.391309e-04
# 282  0.000490  0.000980      0.0 -2.712430e-04 -2.714890e-04 -2.677622e-04
# C:\Users\kojal\anaconda3\envs\orbitool\lib\site-packages\ipykernel_launcher.py:75: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# If skewness is less than -1 or greater than 1, the distribution is highly skewed.
# If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.
# If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.
#
# Negative skewness: peak top is to the right from the mean (bigger tail on the left).

# %% [markdown]
# ## plotPeak
#
# Choose a peak index from the printed dataframe (above) and
# plot the peak for the formula in question.
#
# NOTE:  Peak index that is not in the dataframe gives an error. (to be fixed)

# %%
plotPeak(29,peaklist)  # 2, 8, 215, 269
# Out:
# Peak of interest:  HO6N2-

# %% [markdown]
# ## plotGaussian
#
# Choose a peak index from the printed dataframe (above) and
#
# plot the peak data and Gaussian fit data for the formula in question.
#
# NOTE:  Peak index that is not in the dataframe gives an error. (to be fixed)

# %%
plotGaussian(282, peaklist)
# Out:
# Peak of interest:  C10H14O11N-
#                 x           y
# index
# 0      324.055388    0.000000
# 1      324.055734    9.256354
# 2      324.056080  106.557973
# 3      324.056426  336.684631
# 4      324.056771  497.885896
# 5      324.057117  510.572161
# 6      324.057463  380.424358
# 7      324.057809   96.109598
# 8      324.058155    0.000000
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 9
#     # data points      = 9
#     # variables        = 3
#     chi-square         = 6002.26272
#     reduced chi-square = 1000.37712
#     Akaike info crit   = 64.5240050
#     Bayesian info crit = 65.1156787
# [[Variables]]
#     amplitude:  0.68990510 +/- 0.03025226 (4.38%) (init = 0.7945859)
#     center:     324.056962 +/- 2.5226e-05 (0.00%) (init = 324.0569)
#     sigma:      4.9688e-04 +/- 2.5283e-05 (5.09%) (init = 0.0005187552)
#     fwhm:       0.00117007 +/- 5.9537e-05 (5.09%) == '2.3548200*sigma'
#     height:     553.919441 +/- 24.3404639 (4.39%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, sigma) =  0.578

# %% [markdown]
# ## readMultipleSpectra¶
#
# A method to collect data from multiple spectra. Try it first with a small number of spectra.
# (In a desktop PC, handles about 10 spectra / minute.)
#
# First, it is necessary to establish a new dataframe for all values of interest.
#
# ( This method was simpler, originally, so refactoring is recommended. )

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

ionFolder = "<add your folder name here>/KOionfolder/"  # This file has a different structure than JKo ion file
ionFileName = ionFolder + "Allions1ex.csv"
dfBase = pd.read_csv(ionFileName, sep=",")
dfSize = len(dfBase)
dfBase['idx'] = dfBase.index.to_numpy() 
dfBase['count'] = np.zeros(len(dfBase), dtype="uint32")
zeroBase = np.zeros(len(dfBase), dtype="uint32")
dfBase['sum'] = np.zeros(len(dfBase))
dfBase['new'] = np.zeros(len(dfBase))

#print(dfBase)         # dfBase is the Base dataframe, which is copied to other dataframes

errors = dfBase.copy()
errorsG = dfBase.copy()
errorsL = dfBase.copy()
areas = dfBase.copy()

step = 11        # With step, you read the first spectrum and then every step'th spectrum. 
count = 239      # 239 is 1/11 of the number of files (2626) in THAT folder in readSpectrum(n)
colBase = "t-"
for i in range(count):
    n = i*step
    colName = colBase+str(i)
    
    data = readSpectrum(n)
    peaklist = identifyPeaks(data, pd.read_csv(ionFileName, sep=","), 0.001)
    peaklist['idx'] = peaklist.index.to_numpy()    # Add index value into column 9

    peaklist['centerG'] = np.zeros(len(peaklist['mz']))   #10
    peaklist['sigmaG']  = np.zeros(len(peaklist['mz']))   #11
    peaklist['fwhmG'] = np.zeros(len(peaklist['mz']))   #12  

    peaklist['centerL'] = np.zeros(len(peaklist['mz']))   #13
    peaklist['sigmaL']  = np.zeros(len(peaklist['mz']))   #14
    peaklist['fwhmL'] = np.zeros(len(peaklist['mz']))   #15  
    
    addGaussians(peaklist)

    peaklist['error'] = peaklist['observed'] - peaklist['mz'] # 16
    peaklist['errorG'] = peaklist['centerG'] - peaklist['mz'] # 17
    peaklist['errorL'] = peaklist['centerL'] - peaklist['mz'] # 18

# These need all be zeroed before the loop
    for k in range(len(dfBase)):
        errors.loc[k,'new']=0
        errorsG.loc[k,'new']=0
        errorsL.loc[k,'new']=0
        areas.loc[k,'new']=0
        
    for j in range(len(peaklist)):
#        zeroBase[peaklist.iloc[j,9]]=1
        errors.loc[peaklist.iloc[j,9],'count'] += 1
        errors.loc[peaklist.iloc[j,9],'new'] = peaklist.iloc[j,16]
        errorsG.loc[peaklist.iloc[j,9],'count'] += 1
        errorsG.loc[peaklist.iloc[j,9],'new'] = peaklist.iloc[j,17]  
        errorsL.loc[peaklist.iloc[j,9],'count'] += 1
        errorsL.loc[peaklist.iloc[j,9],'new'] = peaklist.iloc[j,18]
        areas.loc[peaklist.iloc[j,9],'count'] += 1
        areas.loc[peaklist.iloc[j,9],'new'] = peaklist.iloc[j,4]
        
    errors[colName] = errors['new']
    errors['sum'] += errors['new']
    errorsG[colName] = errorsG['new']
    errorsG['sum'] += errorsG['new']
    errorsL[colName] = errorsL['new']
    errorsL['sum'] += errorsL['new']
    areas[colName] = areas['new']
    areas['sum'] += areas['new']
    
print("DONE!")
# Out:
# 0  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T16-56-06.csv
# Shape:      1593, 2
#
# 11  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T16-58-06.csv
# Shape:      1596, 2
#
# 22  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-00-07.csv
# Shape:      1628, 2
#
# 33  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-02-08.csv
# Shape:      1598, 2
#
# 44  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-04-09.csv
# Shape:      1655, 2
#
# 55  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-06-09.csv
# Shape:      1658, 2
#
# 66  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-08-10.csv
# Shape:      1610, 2
#
# 77  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-10-11.csv
# Shape:      1696, 2
#
# 88  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-12-11.csv
# Shape:      1647, 2
#
# 99  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-14-12.csv
# Shape:      1543, 2
#
# 110  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-16-13.csv
# Shape:      1639, 2
#
# 121  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-18-14.csv
# Shape:      1675, 2
#
# 132  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-20-14.csv
# Shape:      1592, 2
#
# 143  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-22-15.csv
# Shape:      1479, 2
#
# 154  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-24-16.csv
# Shape:      1646, 2
#
# 165  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-26-16.csv
# Shape:      1646, 2
#
# 176  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-28-17.csv
# Shape:      1720, 2
#
# 187  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-30-18.csv
# Shape:      1718, 2
#
# 198  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-32-19.csv
# Shape:      1679, 2
#
# 209  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-34-19.csv
# Shape:      1639, 2
#
# 220  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-36-20.csv
# Shape:      1611, 2
#
# 231  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-38-21.csv
# Shape:      1630, 2
#
# 242  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-40-22.csv
# Shape:      1666, 2
#
# 253  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-42-22.csv
# Shape:      1527, 2
#
# 264  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-44-23.csv
# Shape:      1606, 2
#
# 275  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-46-24.csv
# Shape:      1528, 2
#
# 286  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-48-24.csv
# Shape:      1576, 2
#
# 297  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-50-25.csv
# Shape:      1578, 2
#
# 308  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-52-26.csv
# Shape:      1654, 2
#
# 319  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-54-26.csv
# Shape:      1746, 2
#
# 330  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-56-35.csv
# Shape:      1543, 2
#
# 341  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T17-58-36.csv
# Shape:      1581, 2
#
# 352  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-00-37.csv
# Shape:      1691, 2
#
# 363  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-02-37.csv
# Shape:      1547, 2
#
# 374  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-04-38.csv
# Shape:      1641, 2
#
# 385  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-06-39.csv
# Shape:      1560, 2
#
# 396  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-08-40.csv
# Shape:      1579, 2
#
# 407  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-10-40.csv
# Shape:      1657, 2
#
# 418  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-12-41.csv
# Shape:      1504, 2
#
# 429  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-14-42.csv
# Shape:      1665, 2
#
# 440  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-16-42.csv
# Shape:      1770, 2
#
# 451  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-18-43.csv
# Shape:      1580, 2
#
# 462  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-20-44.csv
# Shape:      1626, 2
#
# 473  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-22-45.csv
# Shape:      1607, 2
#
# 484  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-24-45.csv
# Shape:      1594, 2
#
# 495  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-26-46.csv
# Shape:      1610, 2
#
# 506  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-28-47.csv
# Shape:      1593, 2
#
# 517  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-30-47.csv
# Shape:      1550, 2
#
# 528  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-32-48.csv
# Shape:      1521, 2
#
# 539  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-34-49.csv
# Shape:      1743, 2
#
# 550  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-36-52.csv
# Shape:      1572, 2
#
# 561  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-38-53.csv
# Shape:      1512, 2
#
# 572  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-40-54.csv
# Shape:      1569, 2
#
# 583  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-42-54.csv
# Shape:      1566, 2
#
# 594  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-44-55.csv
# Shape:      1668, 2
#
# 605  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-46-56.csv
# Shape:      1680, 2
#
# 616  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-48-56.csv
# Shape:      1585, 2
#
# 627  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-50-57.csv
# Shape:      1551, 2
#
# 638  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-52-58.csv
# Shape:      1639, 2
#
# 649  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-54-59.csv
# Shape:      1602, 2
#
# 660  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-57-07.csv
# Shape:      1730, 2
#
# 671  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T18-59-08.csv
# Shape:      1609, 2
#
# 682  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-01-09.csv
# Shape:      1651, 2
#
# 693  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-03-09.csv
# Shape:      1594, 2
#
# 704  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-05-10.csv
# Shape:      1579, 2
# 715  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-07-11.csv
# Shape:      1533, 2
#
# 726  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-09-12.csv
# Shape:      1589, 2
#
# 737  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-11-12.csv
# Shape:      1638, 2
#
# 748  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-13-13.csv
# Shape:      1535, 2
#
# 759  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-15-14.csv
# Shape:      1648, 2
#
# 770  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-17-14.csv
# Shape:      1537, 2
#
# 781  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-19-15.csv
# Shape:      1581, 2
#
# 792  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-21-16.csv
# Shape:      1557, 2
#
# 803  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-23-16.csv
# Shape:      1669, 2
#
# 814  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-25-17.csv
# Shape:      1635, 2
#
# 825  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-27-18.csv
# Shape:      1578, 2
#
# 836  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-29-19.csv
# Shape:      1651, 2
#
# 847  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-31-19.csv
# Shape:      1712, 2
#
# 858  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-33-20.csv
# Shape:      1687, 2
#
# 869  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-35-21.csv
# Shape:      1596, 2
#
# 880  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-37-21.csv
# Shape:      1512, 2
#
# 891  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-39-22.csv
# Shape:      1670, 2
#
# 902  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-41-23.csv
# Shape:      1599, 2
#
# 913  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-43-23.csv
# Shape:      1595, 2
#
# 924  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-45-24.csv
# Shape:      1727, 2
#
# 935  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-47-25.csv
# Shape:      1584, 2
#
# 946  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-49-26.csv
# Shape:      1673, 2
#
# 957  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-51-26.csv
# Shape:      1647, 2
#
# 968  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-53-27.csv
# Shape:      1692, 2
#
# 979  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-55-28.csv
# Shape:      1511, 2
#
# 990  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-57-39.csv
# Shape:      1693, 2
#
# 1001  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T19-59-40.csv
# Shape:      1631, 2
#
# 1012  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-01-40.csv
# Shape:      1627, 2
#
# 1023  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-03-41.csv
# Shape:      1630, 2
#
# 1034  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-05-42.csv
# Shape:      1628, 2
#
# 1045  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-07-42.csv
# Shape:      1622, 2
#
# 1056  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-09-43.csv
# Shape:      1585, 2
#
# 1067  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-11-44.csv
# Shape:      1651, 2
#
# 1078  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-13-45.csv
# Shape:      1633, 2
#
# 1089  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-15-45.csv
# Shape:      1539, 2
#
# 1100  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-17-46.csv
# Shape:      1676, 2
#
# 1111  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-19-47.csv
# Shape:      1434, 2
#
# 1122  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-21-47.csv
# Shape:      1730, 2
#
# 1133  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-23-48.csv
# Shape:      1456, 2
#
# 1144  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-25-49.csv
# Shape:      1472, 2
#
# 1155  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-27-49.csv
# Shape:      1605, 2
#
# 1166  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-29-50.csv
# Shape:      1704, 2
#
# 1177  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-31-51.csv
# Shape:      1673, 2
#
# 1188  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-33-52.csv
# Shape:      1677, 2
#
# 1199  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-35-52.csv
# Shape:      1618, 2
#
# 1210  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-37-53.csv
# Shape:      1607, 2
#
# 1221  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-39-54.csv
# Shape:      1584, 2
#
# 1232  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-41-54.csv
# Shape:      1645, 2
#
# 1243  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-43-55.csv
# Shape:      1653, 2
#
# 1254  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-45-56.csv
# Shape:      1623, 2
#
# 1265  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-47-56.csv
# Shape:      1600, 2
#
# 1276  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-49-57.csv
# Shape:      1629, 2
#
# 1287  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-51-58.csv
# Shape:      1552, 2
#
# 1298  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-53-58.csv
# Shape:      1700, 2
#
# 1309  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-55-59.csv
# Shape:      1613, 2
#
# 1320  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T20-58-09.csv
# Shape:      1563, 2
#
# 1331  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-00-09.csv
# Shape:      1645, 2
#
# 1342  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-02-10.csv
# Shape:      1596, 2
#
# 1353  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-04-11.csv
# Shape:      1547, 2
#
# 1364  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-06-12.csv
# Shape:      1519, 2
#
# 1375  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-08-12.csv
# Shape:      1705, 2
#
# 1386  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-10-13.csv
# Shape:      1567, 2
#
# 1397  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-12-13.csv
# Shape:      1660, 2
#
# 1408  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-14-14.csv
# Shape:      1663, 2
# 1419  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-16-15.csv
# Shape:      1630, 2
#
# 1430  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-18-15.csv
# Shape:      1577, 2
#
# 1441  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-20-16.csv
# Shape:      1583, 2
#
# 1452  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-22-17.csv
# Shape:      1633, 2
#
# 1463  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-24-20.csv
# Shape:      1594, 2
#
# 1474  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-26-20.csv
# Shape:      1681, 2
#
# 1485  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-28-21.csv
# Shape:      1674, 2
#
# 1496  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-30-21.csv
# Shape:      1696, 2
#
# 1507  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-32-22.csv
# Shape:      1593, 2
#
# 1518  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-34-23.csv
# Shape:      1688, 2
#
# 1529  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-36-23.csv
# Shape:      1648, 2
#
# 1540  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-38-24.csv
# Shape:      1628, 2
#
# 1551  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-40-25.csv
# Shape:      1623, 2
#
# 1562  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-42-26.csv
# Shape:      1658, 2
#
# 1573  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-44-26.csv
# Shape:      1635, 2
#
# 1584  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-46-27.csv
# Shape:      1612, 2
#
# 1595  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-48-28.csv
# Shape:      1589, 2
#
# 1606  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-50-28.csv
# Shape:      1580, 2
#
# 1617  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-52-29.csv
# Shape:      1637, 2
#
# 1628  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-54-30.csv
# Shape:      1666, 2
#
# 1639  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-56-30.csv
# Shape:      1597, 2
#
# 1650  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T21-58-40.csv
# Shape:      1649, 2
#
# 1661  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-00-40.csv
# Shape:      1705, 2
#
# 1672  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-02-41.csv
# Shape:      1630, 2
#
# 1683  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-04-42.csv
# Shape:      1572, 2
#
# 1694  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-06-42.csv
# Shape:      1588, 2
#
# 1705  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-08-43.csv
# Shape:      1678, 2
#
# 1716  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-10-44.csv
# Shape:      1519, 2
#
# 1727  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-12-44.csv
# Shape:      1517, 2
#
# 1738  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-14-45.csv
# Shape:      1598, 2
#
# 1749  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-16-46.csv
# Shape:      1686, 2
#
# 1760  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-18-46.csv
# Shape:      1531, 2
#
# 1771  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-20-47.csv
# Shape:      1530, 2
#
# 1782  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-22-48.csv
# Shape:      1561, 2
#
# 1793  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-24-48.csv
# Shape:      1591, 2
#
# 1804  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-26-49.csv
# Shape:      1631, 2
#
# 1815  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-28-49.csv
# Shape:      1599, 2
#
# 1826  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-30-50.csv
# Shape:      1650, 2
#
# 1837  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-32-51.csv
# Shape:      1591, 2
#
# 1848  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-34-51.csv
# Shape:      1695, 2
#
# 1859  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-36-52.csv
# Shape:      1614, 2
#
# 1870  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-38-53.csv
# Shape:      1639, 2
#
# 1881  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-40-53.csv
# Shape:      1639, 2
#
# 1892  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-42-54.csv
# Shape:      1570, 2
#
# 1903  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-44-55.csv
# Shape:      1646, 2
#
# 1914  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-46-55.csv
# Shape:      1582, 2
#
# 1925  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-48-56.csv
# Shape:      1564, 2
#
# 1936  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-50-57.csv
# Shape:      1573, 2
#
# 1947  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-52-57.csv
# Shape:      1561, 2
#
# 1958  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-54-58.csv
# Shape:      1476, 2
#
# 1969  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-57-08.csv
# Shape:      1674, 2
#
# 1980  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T22-59-08.csv
# Shape:      1719, 2
#
# 1991  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-01-09.csv
# Shape:      1517, 2
#
# 2002  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-03-10.csv
# Shape:      1604, 2
#
# 2013  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-05-10.csv
# Shape:      1683, 2
#
# 2024  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-07-11.csv
# Shape:      1560, 2
#
# 2035  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-09-12.csv
# Shape:      1654, 2
#
# 2046  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-11-12.csv
# Shape:      1588, 2
#
# 2057  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-13-13.csv
# Shape:      1625, 2
#
# 2068  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-15-13.csv
# Shape:      1589, 2
#
# 2079  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-17-14.csv
# Shape:      1552, 2
#
# 2090  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-19-15.csv
# Shape:      1505, 2
#
# 2101  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-21-15.csv
# Shape:      1733, 2
#
# 2112  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-23-16.csv
# Shape:      1565, 2
# 2123  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-25-17.csv
# Shape:      1667, 2
#
# 2134  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-27-17.csv
# Shape:      1589, 2
#
# 2145  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-29-18.csv
# Shape:      1524, 2
#
# 2156  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-31-19.csv
# Shape:      1606, 2
#
# 2167  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-33-19.csv
# Shape:      1533, 2
#
# 2178  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-35-20.csv
# Shape:      1759, 2
#
# 2189  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-37-21.csv
# Shape:      1579, 2
#
# 2200  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-39-21.csv
# Shape:      1546, 2
#
# 2211  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-41-22.csv
# Shape:      1615, 2
#
# 2222  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-43-23.csv
# Shape:      1611, 2
#
# 2233  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-45-23.csv
# Shape:      1690, 2
#
# 2244  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-47-24.csv
# Shape:      1586, 2
#
# 2255  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-49-24.csv
# Shape:      1567, 2
#
# 2266  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-51-25.csv
# Shape:      1708, 2
#
# 2277  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-53-26.csv
# Shape:      1620, 2
#
# 2288  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-55-26.csv
# Shape:      1653, 2
#
# 2299  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-57-35.csv
# Shape:      1756, 2
#
# 2310  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-17T23-59-36.csv
# Shape:      1576, 2
#
# 2321  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-01-36.csv
# Shape:      1578, 2
#
# 2332  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-03-37.csv
# Shape:      1604, 2
#
# 2343  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-05-38.csv
# Shape:      1571, 2
#
# 2354  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-07-38.csv
# Shape:      1623, 2
#
# 2365  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-09-39.csv
# Shape:      1144, 2
#
# 2376  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-11-42.csv
# Shape:      1655, 2
#
# 2387  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-13-42.csv
# Shape:      1634, 2
#
# 2398  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-15-43.csv
# Shape:      1606, 2
#
# 2409  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-17-43.csv
# Shape:      1581, 2
#
# 2420  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-19-44.csv
# Shape:      1635, 2
#
# 2431  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-21-45.csv
# Shape:      1727, 2
#
# 2442  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-23-45.csv
# Shape:      1625, 2
#
# 2453  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-25-46.csv
# Shape:      1603, 2
#
# 2464  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-27-47.csv
# Shape:      1562, 2
#
# 2475  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-29-47.csv
# Shape:      1574, 2
#
# 2486  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-31-48.csv
# Shape:      1562, 2
#
# 2497  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-33-49.csv
# Shape:      1539, 2
#
# 2508  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-35-49.csv
# Shape:      1505, 2
#
# 2519  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-37-50.csv
# Shape:      1631, 2
#
# 2530  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-39-50.csv
# Shape:      1662, 2
#
# 2541  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-41-51.csv
# Shape:      1601, 2
#
# 2552  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-43-52.csv
# Shape:      1648, 2
#
# 2563  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-45-52.csv
# Shape:      1580, 2
#
# 2574  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-47-53.csv
# Shape:      1573, 2
#
# 2585  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-49-54.csv
# Shape:      1661, 2
#
# 2596  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-51-54.csv
# Shape:      1653, 2
#
# 2607  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-53-55.csv
# Shape:      1548, 2
#
# 2618  File name:  C:/datascienceproject/raw data/small mass deviation/deno201117n10\2020-11-18T00-55-55.csv
# Shape:      1571, 2
#
# DONE!

# %% [markdown]
# # Code
#
# Code to plot some data for the Final report.
#
# NOTE1: set the dropLimit!
# ..to print only those ions which occurred more than dropLimit times when reading multiple spectra.
#
# Maximum dropLimit is the number of spectra read in readMultipleSpectra.
#
# NOTE2: This code (and other codes below) works only after a succesful run of readMultipleSpectra.

# %%
dropLimit = 120                                                    #  <===  OBS OBS OBS !!!!

errors2 = errors.copy()
errors2['ave'] = errors2['sum']/errors2['count']
errorsG2 = errorsG.copy()
errorsG2['ave'] = errorsG2['sum']/errorsG2['count']
errorsL2 = errorsL.copy()
errorsL2['ave'] = errorsL2['sum']/errorsL2['count']
areas2 = areas.copy()
areas2['ave'] = areas2['sum']/areas2['count']

print("------ --------------- -----")
areas2 = areas2[areas2.loc[:,'idx'] != 1]     # Big NO3- peak removed
areas2 = areas2[areas2.loc[:,'idx'] != 29]    # Another big peak removed
errors2 = errors2[errors2.loc[:,'idx'] != 1]     # Big NO3- peak removed
errors2 = errors2[errors2.loc[:,'idx'] != 29]    # Another big peak removed
errorsG2 = errorsG2[errorsG2.loc[:,'idx'] != 1]     # Big NO3- peak removed
errorsG2 = errorsG2[errorsG2.loc[:,'idx'] != 29]    # Another big peak removed
errorsL2 = errorsL2[errorsL2.loc[:,'idx'] != 1]     # Big NO3- peak removed
errorsL2 = errorsL2[errorsL2.loc[:,'idx'] != 29]    # Another big peak removed
print(len(errors2))

errors2 = errors2[errors.loc[:,'count'] > dropLimit]
errorsG2 = errorsG2[errorsG2.loc[:,'count'] > dropLimit]
errorsL2 = errorsL2[errorsL2.loc[:,'count'] > dropLimit]
areas2 = areas2[areas2.loc[:,'count'] > dropLimit]
print(len(errors2))

# Removing all values with NaN (that is, ion was not detected)
#errors2 = errors2.dropna()
#errorsG2 = errorsG2.dropna()
#errorsL2 = errorsL2.dropna()
#areas2 = areas2.dropna()


print(errors2)
print(errorsG2)
print(errorsL2)
print(areas2[:10])


print("-----------")
print(errorsG2.loc[:,'ave']-errors2.loc[:,'ave'])
print(errorsL2.loc[:,'ave']-errors2.loc[:,'ave'])
# Out:
# ------ --------------- -----
# 290
# 66
#             formula          mz  idx  count       sum       new       t-0  \
# 2          O3N[15]-   62.985401    2    239  0.005742  0.000023  0.000023
# 3         O2O[17]N-   62.992584    3    239  0.005040  0.000024  0.000022
# 4         O2O[18]N-   63.992613    4    239  0.002641  0.000010  0.000009
# 9            C2HO4-   88.988032    9    239  0.021223  0.000090  0.000080
# 15          C3H3O4-  103.003682   15    239  0.019523  0.000080  0.000087
# ..              ...         ...  ...    ...       ...       ...       ...
# 254  C9C[13]H16O9N-  295.086410  254    199  0.000505  0.000055 -0.000126
# 262     C14H16O5NF-  297.101799  262    237  0.015651  0.000033  0.000166
# 269     C10H14O10N-  308.062319  269    238 -0.027294 -0.000127 -0.000065
# 274     C10H16O10N-  310.077969  274    218 -0.029928  0.000078 -0.000239
# 282     C10H14O11N-  324.057234  282    174 -0.015906  0.000126 -0.000271
#
#           t-1       t-2       t-3  ...     t-230     t-231     t-232  \
# 2    0.000020  0.000025  0.000023  ...  0.000027  0.000025  0.000022
# 3    0.000018  0.000019  0.000017  ...  0.000023  0.000019  0.000018
# 4    0.000009  0.000010  0.000010  ...  0.000010  0.000009  0.000010
# 9    0.000088  0.000089  0.000083  ...  0.000091  0.000091  0.000089
# 15   0.000088  0.000087  0.000075  ...  0.000079  0.000082  0.000085
# ..        ...       ...       ...  ...       ...       ...       ...
# 254  0.000000  0.000171  0.000000  ... -0.000235  0.000128  0.000054
# 262 -0.000023  0.000039  0.000085  ...  0.000023  0.000130  0.000038
# 269 -0.000193 -0.000202 -0.000100  ... -0.000039 -0.000191 -0.000181
# 274 -0.000173 -0.000351  0.000000  ... -0.000149 -0.000035 -0.000179
# 282 -0.000174  0.000004  0.000000  ... -0.000318 -0.000103 -0.000032
#
#             t-233     t-234     t-235     t-236     t-237     t-238       ave
# 2    2.475318e-05  0.000023  0.000023  0.000028  0.000025  0.000023  0.000024
# 3    2.686723e-05  0.000020  0.000020  0.000025  0.000017  0.000024  0.000021
# 4    1.315844e-05  0.000012  0.000012  0.000009  0.000012  0.000010  0.000011
# 9    9.598247e-05  0.000091  0.000101  0.000089  0.000092  0.000090  0.000089
# 15   8.815118e-05  0.000091  0.000085  0.000081  0.000081  0.000080  0.000082
# ..            ...       ...       ...       ...       ...       ...       ...
# 254  4.202560e-05  0.000135 -0.000074 -0.000089  0.000010  0.000055  0.000003
# 274  0.000000e+00 -0.000064 -0.000110 -0.000110  0.000029  0.000078 -0.000137
# 282  9.429672e-07  0.000000 -0.000097 -0.000057 -0.000061  0.000126 -0.000091
#
# [16 rows x 246 columns]

# %%
x = errors2['mz']
y = errors2['ave']
fig = plt.figure()
plt.scatter(x,y)

#To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("m/z")
plt.ylabel("Average error of means")
plt.title("Peak identified at least once")
plt.show()


x = errorsG2['mz']
y = errorsG2['ave']
fig = plt.figure()
#plt.scatter(x,y, color = "red")
plt.scatter(x,y)

#To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("m/z")
plt.ylabel("Average error of Gaussians")
plt.title("Peak identified at least half the times")
plt.show()


x = errorsL2['mz']
y = errorsL2['ave']
fig = plt.figure()
#plt.scatter(x,y,color = "green")
plt.scatter(x,y)

#To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("m/z")
plt.ylabel("Average error of Lorentzians")
plt.title("Peak identified at least once")
plt.show()

x = areas2['mz']
y = areas2['ave']
fig = plt.figure()
plt.scatter(x,y)

#To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("m/z")
plt.ylabel("Area")
plt.title("Areas as function of m / z")
plt.show()

# ------------------------------------------------------------------------------

x = errorsG2['mz']
y = errorsG2.loc[:,'ave']-errors2.loc[:,'ave']
fig = plt.figure()
plt.scatter(x,y)

#To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("m/z")
plt.ylabel("Average difference in error")
plt.title("Gaussian fit error - weighted mean error")
plt.show()


x = errorsL2['mz']
y = errorsL2.loc[:,'ave']-errors2.loc[:,'ave']
fig = plt.figure()
plt.scatter(x,y)

#To see the names of compounds in the graph, uncomment these 2 lines:
#for i,j,k in zip(x,y,k):
#    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("m/z")
plt.ylabel("Average difference in error")
plt.title("Lorenzian fit error - weighted mean error")
plt.show()


#  Here use pyplot to annotate

xmz = errorsL2['mz']
ydiff = errorsL2.loc[:,'ave']-errors2.loc[:,'ave'] 
names = errorsL2['formula']
pit = len(xmz)

y = ydiff
x = xmz
fig = plt.figure()
plt.scatter(x,y)

k = names
# To see the names of compounds in the graph, uncomment these lines:
ax = fig.add_subplot(111)   # subplot not working as expected
for i,j,k in zip(x,y,k):
    ax.annotate(str(k),xy=(i+0.4,j), fontsize = 9)

plt.xlabel("Molar mass (mz)")
plt.ylabel("Error (Lorenzian error - means error)")
#plt.figure(figsize=(3,2))           # not working right
#plt.figure(figsize=(6, 4), dpi=70)  # not working right
plt.show()

print(errors2.iloc[:,0:4])
# Out:
# C:\Users\kojal\anaconda3\envs\orbitool\lib\site-packages\ipykernel_launcher.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#             formula          mz  idx  count
# 2          O3N[15]-   62.985401    2    239
# 3         O2O[17]N-   62.992584    3    239
# 4         O2O[18]N-   63.992613    4    239
# 9            C2HO4-   88.988032    9    239
# 15          C3H3O4-  103.003682   15    239
# ..              ...         ...  ...    ...
# 254  C9C[13]H16O9N-  295.086410  254    199
# 262     C14H16O5NF-  297.101799  262    237
# 269     C10H14O10N-  308.062319  269    238
# 274     C10H16O10N-  310.077969  274    218
# 282     C10H14O11N-  324.057234  282    174
#
# [66 rows x 4 columns]

# %% [markdown]
# ## Plot ion error as function of time
#
# Put the ion number into variable nm  e.g. 2 (+) or  25 (-)
#
# Note: there may be no recordings on that ion number.
#
# Ion 1 (NO3-) givess some single high error values!

# %%
import seaborn as sns

nm = 25
data = errors[errors['idx']==nm].to_numpy().copy()
data = data[0]
sCount = 239   # How many spectra 239

x = np.arange(sCount)
y = data[6:len(data)]

sns.set_style('ticks')
sns.regplot(x, y, ci=None)
sns.despine()
plt.xlabel('Measurement N')
plt.ylabel('Absolute error')
plt.title(data[0])

plt.show()   # with this, you get 2 separate graphs

nm = 2
data = errors[errors['idx']==nm].to_numpy().copy()
data = data[0]

x = np.arange(sCount)
y = data[6:len(data)]

sns.set_style('ticks')
sns.regplot(x, y, ci=None)
sns.despine()
plt.xlabel('Measurement N')
plt.ylabel('Absolute error')
plt.title(data[0])

plt.show()
# Out:
# C:\Users\kojal\anaconda3\envs\orbitool\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\kojal\anaconda3\envs\orbitool\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Use this method if you want to export some key data

errors.to_csv('errors.csv')
errors2.to_csv('errors2.csv')
errorsG.to_csv('errorsG.csv')
errorsG2.to_csv('errorsG2.csv')
errorsL.to_csv('errorsL.csv')
errorsL2.to_csv('errorsL2.csv')
areas.to_csv('areas.csv')
areas2.to_csv('areas2.csv')

# %% [markdown]
# # Figure 3
#
# Code to plot Figure 3 in Final report.
#
# NOTE: Ions are also printed in order of occurrence.
# See the code section titled #Code above: only those ions are printed, which accirred more than dropLimit times.

# %%
list = errors.copy()

list.sort_values("count", inplace=True)

#list
ccc = list['count'].to_numpy()
ccc
x = np.arange(len(ccc))
plt.scatter(x,ccc, s=10)
plt.xlabel('Ordered ion')
plt.ylabel('Counts detected')
plt.title('Ions detected in 239 measurements')
plt.show()

xxx = list[list['count']>0]
print(len(xxx))
yyy = list[list['count']==239]
print(len(yyy))
print(len(errors))

list2 = errorsG2.copy()
list2.sort_values("count", ascending=False, inplace=True)

list3 = list2.copy()

list3 = list2[['formula', 'mz', 'count', 'ave']].copy()

pd.set_option("display.max_rows", None)
print(list3)
pd.set_option("display.max_rows", 10)
# Out:
# 201
# 35
# 292
#               formula          mz  count           ave
# 149          C5H6O9N-  224.004804    239 -3.229969e-05
# 33        HO5O[18]N2-  126.988256    239 -1.184298e-06
# 136           C8H9O7-  217.035376      2  9.388025e-05
# 173    C8H12O6O[18]N-  236.066172      2  4.970214e-05
# 102          C4H6O8N-  196.009890      2 -7.176282e-05
# 109      C7C[13]H9O6-  202.043816      2 -8.329803e-05
# 205    C6C[13]H10O9N-  253.039459      2 -9.612974e-06
# 91            H2O9N3-  187.979652      2 -1.799364e-05
# 165          C9H13O7-  233.066676      2 -7.287876e-05
# 129           C9H9O6-  213.040462      2 -6.286956e-05
# 183         C11H15O6-  243.087412      1 -8.198753e-05
# 139     C8C[13]H13O6-  218.075117      1  1.005332e-04
# 287       C10H16O11N-  326.072884      1 -3.453774e-04
# 152    C5C[13]H10O8N-  225.044545      1  8.351728e-05
# 285   C9C[13]H14O11N-  325.060589      1 -8.631185e-05
# 134     C8C[13]H11O6-  216.059466      1 -7.902086e-05
# 270        C11H18O9N-  308.098705      1  3.130522e-04
# 21            C5H5O3-  113.024418      1  7.271887e-05
# 22            C6H9O2-  113.060803      1  9.299716e-05
# 182         C6H10O9N-  240.036104      1 -4.121943e-05
# 263  C13C[13]H16O5NF-  298.105154      1  1.540320e-05
# 164     C9C[13]H15O6-  232.090767      1 -1.098683e-05
# 178    C7H10O7O[18]N-  238.045436      1 -1.348662e-04
# 189         C10H15O7-  247.082326      1 -7.053324e-05
# 261   C8C[13]H14O10N-  297.065674      1 -1.567798e-04
# 60           C7H11O4-  159.066282      1  9.964283e-05
# 79       C5C[13]H7O6-  176.028166      1  3.176102e-05
# 82            C6H9O6-  177.040462      1 -1.146880e-04
# 232     C9H11H[2]O9N-  279.058031      1 -1.681526e-04
# 53       C5H7O4O[18]-  149.034143      1  9.516096e-06
# 238        C10H18O8N-  280.103790      1  1.242707e-04
# 49            C6H9O4-  145.050632      1 -7.428521e-05
# 243    C9H14O8O[18]N-  282.071651      1 -3.305121e-05
# 122     C4C[13]H6O8N-  209.013245      1 -7.478787e-05
# 46            C7H9O3-  141.055718      1  2.808619e-05
# 45            C3O3F3-  140.980502      1 -1.974524e-05
# 43       C3C[13]H5O5-  134.017602      1  1.176684e-04
# 190          C7H6O9N-  248.004804      1 -7.607240e-05
# 39            C4H3O5-  130.998597      1  3.463560e-05
# 255    C10H15H[2]O9N-  295.089331      1 -1.326372e-04
# 256  C7C[13]H11O10N2-  296.045273      1 -1.451753e-04
# 291      C10H15O11N2-  339.068133      1  7.848267e-05
#               formula          mz  count       ave
# 149          C5H6O9N-  224.004804    239 -0.000032
# 33        HO5O[18]N2-  126.988256    239 -0.000001
# 252        C10H16O9N-  294.083055    239 -0.000219
# 90           C8H11O5-  187.061197    239 -0.000010
# 248        C10H14O9N-  292.067405    239 -0.000224
# ..                ...         ...    ...       ...
# 190          C7H6O9N-  248.004804      1 -0.000076
# 39            C4H3O5-  130.998597      1  0.000035
# 255    C10H15H[2]O9N-  295.089331      1 -0.000133
# 256  C7C[13]H11O10N2-  296.045273      1 -0.000145
# 291      C10H15O11N2-  339.068133      1  0.000078
#
# [199 rows x 4 columns]
